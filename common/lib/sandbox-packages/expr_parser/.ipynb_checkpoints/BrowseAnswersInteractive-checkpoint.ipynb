# %%
import requests
import pandas as pd
import numpy as np
from IPython.html.widgets import interact, interactive, fixed
from IPython.html import widgets
from IPython.display import clear_output, display, HTML
from collections import OrderedDict

# %%
# Load all course data
url = 'http://webwork.cse.ucsd.edu:4351/answers_by_part'
course='UCSD_CSE103'
r = requests.get(url, params={'course':course})
data=r.json()
DF = pd.DataFrame(data)

# %%
# Create dropdowns
s=DF.groupby('set_id').size()
s.sort(ascending=False)
sets = OrderedDict([("{0} - {1}".format(k,v), k) for k,v in s.iteritems()])

assignment_picker = widgets.DropdownWidget(values=sets, description="Assignment:")
problem_picker = widgets.DropdownWidget(values=[], description="Problem")
part_picker = widgets.DropdownWidget(values=[], description="Part")
user_picker = widgets.DropdownWidget(values=[], description="User")

# Defaults
assignment = sets.values()[0]
problem = 0
part = 0
user=""
data = DF

# Change listeners
def on_assignment_change(trait_name, new_value):
    global assignment
    assignment = new_value
    update_problems()
    update_users()
    refilter()
    
def on_problem_change(trait_name, new_value):
    global problem
    problem = new_value
    update_parts()
    update_users()
    refilter()

def on_part_change(trait_name, new_value):
    global part
    part = new_value
    update_users()
    refilter()
    
def on_user_change(trait_name, new_value):
    global user
    user = new_value
    refilter()

def update_problems():
    problems = DF[DF['set_id']==assignment].groupby('problem_id').size()
    problems.sort_index()
    problem_picker.values = OrderedDict([("{0} - {1}".format(k,v),k) for k,v in problems.iteritems()])
    
def update_parts():
    parts = DF[(DF['set_id']==assignment) & (DF['problem_id']==problem)].groupby('part_id').size()
    parts.sort_index()
    part_picker.values = OrderedDict([("{0} - {1}".format(k,v),k) for k,v in parts.iteritems()])
    
def update_users():
    global user
    user=""
    user_counts = DF[(DF['set_id']==assignment) & (DF['problem_id']==problem) & (DF['part_id']==part)].groupby('user_id').size()
    user_counts.sort(ascending=False)
    user_picker.values = OrderedDict([("{0} - {1}".format(k,v), k) for k,v in user_counts.iteritems()])

def refilter():
    global data
    data = DF[(DF['set_id']==assignment) & (DF['problem_id']==problem) & (DF['part_id']==part) & (DF['user_id'].str.startswith(user))]
    
assignment_picker.on_trait_change(on_assignment_change, 'value')
problem_picker.on_trait_change(on_problem_change, 'value')
part_picker.on_trait_change(on_part_change, 'value')
user_picker.on_trait_change(on_user_change, 'value')

# %%
display(assignment_picker)
display(problem_picker)
display(part_picker)
display(user_picker)

# %%
data.sort('timestamp')
# Out:
#        answer_id                                      answer_string     id  \
# 97175      59875                                            C(47,5)  30606
# 97194      59885                                            C(12,5)  30607
# 97203      59894                                            C(52,5)  30609
# 97209      59898                                 C(52,5) - C(52,36)  30610
# 97214      59902                                  C(52,5) - C(36,5)  30611
# 97224      59909                                            C(12,1)  30612
# 97230      59913                                           C(52,12)  30613
# 97248      59929                                  C(52,1) - C(12,1)  30614
# 97251      59932                                  C(52,1) - C(40,1)  30615
# 97255      59937                                  C(52,1) - C(12,0)  30616
# 97268      59946                                  C(12,1) + C(52,4)  30617
# 97270      59948                                  C(12,1) + C(40,4)  30618
# 97271      59949                                  C(12,1) * C(40,4)  30619
# 97273      59951                                  C(12,1) + C(51,4)  30620
# 97283      59961                          C(52,5) - C(12,0)*C(52,5)  30621
# 97285      59963                          C(12,5) - C(12,0)*C(52,5)  30622
# 97294      59969  C(12,1)*C(51,4) + C(12,2)*C(50,3) + C(12,3)*C(...  30623
# 97297      59972                                        1 - C(12,0)  30624
# 97298      59973                                1 - C(12,0)/C(52,5)  30625
# 97300      59975                                1 - C(12,0)/C(12,5)  30626
# 97302      59977                                1 - C(12,0)/C(42,5)  30627
# 97303      59978                                1 - C(12,0)/C(40,5)  30628
# 97305      59980                                  C(52,5) - C(12,0)  30629
# 97306      59981                                  C(40,5) - C(12,0)  30630
# 97307      59982                                  C(52,5) - C(12,0)  30631
# 97322      59993                                         1 -C(40,5)  30632
# 97326      59996                                  C(52,5) - C(40,5)  30633
# 97334      60003           (C(52,5) - C(40,5)) -(C(52,5) - C(28,5))  30635
# 97338      60006                        C(52,5) - C(40,5) - C(28,5)  30636
# 97344      60011                        C(52,5) - C(40,5) - C(32,5)  30637
# ...          ...                                                ...    ...
# 98143      60615               C(52,5) - C(40,5) + C(32,5) -C(16,5)  30708
# 98150      60618               C(52,5) - C(40,5) + C(32,5) -C(20,5)  30709
# 98151      60619               C(52,5) - C(40,5) + C(32,5) -C(28,5)  30710
# 98152      60620               C(52,5) - C(40,5) + C(32,5) -C(12,5)  30711
# 98153      60621                C(52,5) - C(40,5) + C(32,5) -C(4,1)  30712
# 98160      60624                         C(52,5) - C(40,5)- C(20,5)  30713
# 98163      60627               C(52,5) - C(40,5) - C(32,5)- C(20,5)  30714
# 98166      60629              C(52,5) - C(40,5) - C(32,5) - C(20,5)  30715
# 98168      60631              C(52,5) - C(40,5) + C(32,5) - C(20,5)  30716
# 98258      60707  C(52,5) - C(40,5) + C(32,5) - C(20,5) - (1.940...  30717
# 98259      60708  C(52,5) - C(40,5) + C(32,5) - C(20,5) - (1.940...  30718
# 98262      60710  C(52,5) - C(40,5) + C(32,5) - C(20,5) - ( C(32...  30719
# 98264      60712  C(52,5) - C(40,5) + C(32,5) - C(20,5) - (1.940...  30720
# 98268      60715  C(52,5) - C(40,5) + C(32,5) - C(20,5) - ((1.94...  30721
# 98269      60716  C(52,5) - C(40,5) + C(32,5) - C(20,5) - (1.940...  30722
# 98270      60717  C(52,5) - C(40,5) + C(32,5) - C(20,5) - (1.940...  30723
# 98271      60718  C(52,5) - C(40,5) + C(32,5) - C(20,5) - (1.940...  30724
# 98273      60720  C(52,5) - C(40,5) + C(32,5) - C(20,5) - (1.940...  30725
# 98274      60721  C(52,5) - C(40,5) + C(32,5) - C(20,5) - (1.940...  30726
# 98281      60724  C(52,5) - C(40,5) + C(32,5) - C(20,5) - (1.940...  30727
# 98286      60726  C(52,5) - C(40,5) + C(32,5) - C(20,5) - (1.940...  30728
# 98290      60729  C(52,5) - C(40,5) + C(32,5) - C(20,5) - (C(52,...  30729
# 98307      60742  C(52,5) - C(40,5) + C(32,5) - C(20,5) - (C(52,...  30730
# 98308      60743  C(52,5) - C(40,5) + C(32,5) - C(20,5) - (C(52,...  30731
# 98313      60748  C(52,5) - C(40,5) + C(32,5) - C(20,5) - (C(52,...  30732
# 98396      60818  [C(52,5) - C(40,5)] + C(32,5) - C(20,5) - [C(5...  30733
# 98402      60824  [C(52,5) - C(40,5)] + C(32,5) - C(20,5) - [C(5...  30734
# 98404      60826  [C(52,5) - C(40,5)] + C(32,5) - C(20,5) - [C
# 98269        0           1     0  Assignment10.16.13  2013-10-17T08:20:28
# 98270        0           1     0  Assignment10.16.13  2013-10-17T08:20:51
# 98271        0           1     0  Assignment10.16.13  2013-10-17T08:21:28
# 98273        0           1     0  Assignment10.16.13  2013-10-17T08:21:47
# 98274        0           1     0  Assignment10.16.13  2013-10-17T08:23:02
# 98281        0           1     0  Assignment10.16.13  2013-10-17T08:26:54
# 98286        0           1     0  Assignment10.16.13  2013-10-17T08:27:19
# 98290        0           1     0  Assignment10.16.13  2013-10-17T08:28:23
# 98307        0           1     0  Assignment10.16.13  2013-10-17T08:37:05
# 98308        0           1     0  Assignment10.16.13  2013-10-17T08:37:23
# 98313        0           1     0  Assignment10.16.13  2013-10-17T08:39:28
# 98396        0           1     0  Assignment10.16.13  2013-10-17T09:05:05
# 98402        0           1     0  Assignment10.16.13  2013-10-17T09:10:12
# 98404        0           1     0  Assignment10.16.13  2013-10-17T09:10:50
# 98429        0           1     0  Assignment10.16.13  2013-10-17T09:17:42
# 98430        0           1     1  Assignment10.16.13  2013-10-17T09:17:57
#
#        user_id
# 97175  lahuynh
# 97194  lahuynh
# 97203  lahuynh
# 97209  lahuynh
# 97214  lahuynh
# 97224  lahuynh
# 97230  lahuynh
# 97248  lahuynh
# 97251  lahuynh
# 97255  lahuynh
# 97268  lahuynh
# 97270  lahuynh
# 97271  lahuynh
# 97273  lahuynh
# 97283  lahuynh
# 97285  lahuynh
# 97294  lahuynh
# 97297  lahuynh
# 97298  lahuynh
# 97300  lahuynh
# 97302  lahuynh
# 97303  lahuynh
# 97305  lahuynh
# 97306  lahuynh
# 97307  lahuynh
# 97322  lahuynh
# 97326  lahuynh
# 97334  lahuynh
# 97338  lahuynh
# 97344  lahuynh
# ...        ...
# 98143  lahuynh
# 98150  lahuynh
# 98151  lahuynh
# 98152  lahuynh
# 98153  lahuynh
# 98160  lahuynh
# 98163  lahuynh
# 98166  lahuynh
# 98168  lahuynh
# 98258  lahuynh
# 98259  lahuynh
# 98262  lahuynh
# 98264  lahuynh
# 98268  lahuynh
# 98269  lahuynh
# 98270  lahuynh
# 98271  lahuynh
# 98273  lahuynh
# 98274  lahuynh
# 98281  lahuynh
# 98286  lahuynh
# 98290  lahuynh
# 98307  lahuynh
# 98308  lahuynh
# 98313  lahuynh
# 98396  lahuynh
# 98402  lahuynh
# 98404  lahuynh
# 98429  lahuynh
# 98430  lahuynh
#
# [128 rows x 9 columns]

# %% [raw]
# Problem 10.16.13/1
# BEGIN_PGML
#
# *Find the probability that a poker hand of 5 cards from a standard deck will contain no card smaller than 7 (i.e. 2,3...6) (call this event [`A`]), given that it contains at least one face card (i.e. J, Q, K) (call this event [`B`])"?*
#
# We define two events:
# * Event [`A`]: The hand contains no card smaller than 7.
# * Event [`B`]: The hand contains at least one face card.
#
# We start by computing the size of the relevant events
